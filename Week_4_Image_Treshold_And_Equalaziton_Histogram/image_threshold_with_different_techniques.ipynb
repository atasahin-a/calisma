# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
my_img_rgb = cv2.imread("./meymun.jpg" ,1)
my_img_gray = cv2.cvtColor(my_img_rgb, cv2.COLOR_BGR2GRAY)

# %%
_, my_thresh_binary = cv2.threshold(my_img_gray, thresh=128, maxval=255,
                                    type= cv2.THRESH_BINARY)

# %%
fig = plt.figure(figsize=(10,7))
rows = 1
colums = 2
fig.add_subplot(rows,colums,1)
plt.imshow(my_img_gray, cmap="gray")
plt.axis('off')
plt.title("Original image")

fig.add_subplot(rows,colums,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("BINARY THRESHOLDING Image")
# Out:
# Text(0.5, 1.0, 'BINARY THRESHOLDING Image')

# %%
_, my_thresh_binary_inv = cv2.threshold(my_img_gray, thresh=128, maxval=255,
                                    type= cv2.THRESH_BINARY_INV)

# %%
fig = plt.figure(figsize=(10,7))
rows = 1
colums = 3
fig.add_subplot(rows,colums,1)
plt.imshow(my_img_gray, cmap="gray")
plt.axis('off')
plt.title("Original image")

fig.add_subplot(rows,colums,3)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDING Image")
# Out:
# Text(0.5, 1.0, 'BINARY INV THRESHOLDING Image')

# %%
_, my_thresh_trunc = cv2.threshold(my_img_gray, thresh=128, maxval=255,
                                    type= cv2.THRESH_TRUNC)

# %%
fig = plt.figure(figsize=(10,7))
rows = 2
colums = 2
fig.add_subplot(rows,colums,1)
plt.imshow(my_img_gray, cmap="gray")
plt.axis('off')
plt.title("Original image")

fig.add_subplot(rows,colums,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDING Image")

fig.add_subplot(rows,colums,3)
plt.imshow(my_thresh_binary_inv,cmap="gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDING Image")

fig.add_subplot(rows,colums,4)
plt.imshow(my_thresh_trunc,cmap="gray")
plt.axis('off')
plt.title("BINARY TRUNC Image")
# Out:
# Text(0.5, 1.0, 'BINARY TRUNC Image')

# %%
_, my_thresh_tozero = cv2.threshold(my_img_gray, thresh=128, maxval=255,
                                    type= cv2.THRESH_TOZERO)
_, my_thresh_tozero_inv = cv2.threshold(my_img_gray, thresh=128, maxval=255,
                                    type= cv2.THRESH_TOZERO_INV)

# %%
fig = plt.figure(figsize=(10,7))
rows = 2
colums = 3
fig.add_subplot(rows,colums,1)
plt.imshow(my_img_gray, cmap="gray")
plt.axis('off')
plt.title("Original image")

fig.add_subplot(rows,colums,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDING Image")

fig.add_subplot(rows,colums,3)
plt.imshow(my_thresh_binary_inv,cmap="gray")
plt.axis('off')
plt.title("BINARY THRESHOLDING Image")

fig.add_subplot(rows,colums,4)
plt.imshow(my_thresh_trunc,cmap="gray")
plt.axis('off')
plt.title("BINARY TRUNC Image")

fig.add_subplot(rows,colums,5)
plt.imshow(my_thresh_tozero,cmap="gray")
plt.axis('off')
plt.title("Tozero Image")

fig.add_subplot(rows,colums,6)
plt.imshow(my_thresh_trunc,cmap="gray")
plt.axis('off')
plt.title("Tozero inv Image")
# Out:
# Text(0.5, 1.0, 'Tozero inv Image')
